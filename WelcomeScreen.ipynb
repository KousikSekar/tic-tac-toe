# %%
## Gameplay 

import tkinter
from tkinter import messagebox

class playgame:
    global count
    global l
    count = 1
    l = list('a b c d e f g h i'.split())
    global window
    window = tkinter.Tk()
    window.title("Tic Tac Toe")
    window.geometry("520x470")
    window.resizable(0,0)
    
    def grid():
        b00 = tkinter.Button(window,fg='white',bg='white',bd=0,width=24,height=10)
        b00.grid(row=0,column=0)
        b00.bind('<Button-1>',lambda event : chg(event,0,0))
        
        b01 = tkinter.Button(window,fg='white',bg='#CECCCC',bd=0,width=24,height=10)
        b01.grid(row=0,column=1)
        b01.bind('<Button-1>',lambda event : chg(event,0,1))
        
        b02 = tkinter.Button(window,fg='white',bg='white',bd=0,width=24,height=10) 
        b02.grid(row=0,column=2)
        b02.bind('<Button-1>',lambda event : chg(event,0,2))

        b10 = tkinter.Button(window,fg='white',bg='#CECCCC',bd=0,width=24,height=10)
        b10.grid(row=1,column=0)
        b10.bind('<Button-1>',lambda event : chg(event,1,0))

        b11 = tkinter.Button(window,fg='white',bg='white',bd=0,width=24,height=10)
        b11.grid(row=1,column=1)
        b11.bind('<Button-1>',lambda event : chg(event,1,1))

        b12 = tkinter.Button(window,fg='white',bg='#CECCCC',bd=0,width=24,height=10) 
        b12.grid(row=1,column=2)
        b12.bind('<Button-1>',lambda event : chg(event,1,2))

        b20 = tkinter.Button(window,fg='white',bg='white',bd=0,width=24,height=10)
        b20.grid(row=2,column=0)
        b20.bind('<Button-1>',lambda event : chg(event,2,0))

        b21 = tkinter.Button(window,fg='white',bg='#CECCCC',bd=0,width=24,height=10)
        b21.grid(row=2,column=1)
        b21.bind('<Button-1>',lambda event : chg(event,2,1))

        b22 = tkinter.Button(window,fg='white',bg='white',bd=0,width=24,height=10) 
        b22.grid(row=2,column=2)
        b22.bind('<Button-1>',lambda event : chg(event,2,2))

    grid()      
    
    window.mainloop()
              
if __name__ == '__main__':
    playgame()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "D:\learning\Anaconda\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "<ipython-input-9-8fa770b73f9a>", line 36, in <lambda>
#     b11.bind('<Button-1>',lambda event : chg(event,1,1))
# NameError: name 'chg' is not defined
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "D:\learning\Anaconda\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "<ipython-input-9-8fa770b73f9a>", line 48, in <lambda>
#     b21.bind('<Button-1>',lambda event : chg(event,2,1))
# NameError: name 'chg' is not defined
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "D:\learning\Anaconda\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "<ipython-input-9-8fa770b73f9a>", line 32, in <lambda>
#     b10.bind('<Button-1>',lambda event : chg(event,1,0))
# NameError: name 'chg' is not defined
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "D:\learning\Anaconda\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "<ipython-input-9-8fa770b73f9a>", line 40, in <lambda>
#     b12.bind('<Button-1>',lambda event : chg(event,1,2))
# NameError: name 'chg' is not defined
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "D:\learning\Anaconda\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "<ipython-input-9-8fa770b73f9a>", line 48, in <lambda>
#     b21.bind('<Button-1>',lambda event : chg(event,2,1))
# NameError: name 'chg' is not defined
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "D:\learning\Anaconda\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "<ipython-input-9-8fa770b73f9a>", line 52, in <lambda>
#     b22.bind('<Button-1>',lambda event : chg(event,2,2))
# NameError: name 'chg' is not defined

# %%
## Welcome Screen

import tkinter as tk
from PIL import ImageTk, Image

#This creates the main window of an application
window = tk.Tk()
window.title("Join")
window.geometry("520x470")
window['bg'] = 'white'
window.resizable(0,0)


wel_path = r"D:\learning\Python\tic-tac-toe\welcomescreenpng.png"
tic_path = r"D:\learning\Python\tic-tac-toe\TicTacToe2.png"
startgame_path = r"D:\learning\Python\tic-tac-toe\button_start-game.png"
howtoplay_path = r"D:\learning\Python\tic-tac-toe\button_how-to-play.png"
quit_path = r"D:\learning\Python\tic-tac-toe\button_quit.png"


#Creates a Tkinter-compatible photo image, which can be used everywhere Tkinter expects an image object.
wel_img = ImageTk.PhotoImage(Image.open(wel_path))
tic_img = ImageTk.PhotoImage(Image.open(tic_path))
startgame = ImageTk.PhotoImage(Image.open(startgame_path))
howtoplay = ImageTk.PhotoImage(Image.open(howtoplay_path))
quit = ImageTk.PhotoImage(Image.open(quit_path))



#The Label widget is a standard Tkinter widget used to display a text or image on the screen.
wel_panel = tk.Label(window, image = wel_img,anchor='n',background='white',width=530)
tic_panel = tk.Label(window, image= tic_img,anchor='n',background='white',width=530)

start_btn = tk.Button(window,image=startgame,bd=0,bg='white')
howtoplay_btn = tk.Button(window,image=howtoplay,bd=0,bg='white')
quit_btn = tk.Button(window,image=quit,bd=0,bg='white')

#done_by = tk.Label(window,text='-by Kousik',font=('Arial Bold',10),width=200,height=1,bd=0,fg='red',anchor='se',bg='white')


#The Pack geometry manager packs widgets in rows or columns.
#panel.pack(side = "bottom", fill = "both", expand = "yes")
wel_panel.grid(row=0)
tic_panel.grid(row=1)
start_btn.grid(row=2,pady=5)
howtoplay_btn.grid(row=3,pady=5)
quit_btn.grid(row=4,pady=5)
#done_by.grid(row=5)

#Start the GUI
window.mainloop()

# %%
# how to play

import tkinter as tk
from PIL import ImageTk, Image

#This creates the main window of an application
window = tk.Tk()
window.title("Join")
window.geometry("520x470")
window['bg'] = 'white'
window.resizable(0,0)

ins = tk.Label(window,font=('Arial Bold',20),text = "Try to place it consecutively",width=10,fg='Red')
prev_btn = tk.Button(window,anchor='w')
labl = tk.Label(window,width = 10 , height = 10 , fg = 'red',bg='red')

ins.grid(row=0,column=1)
prev_btn.grid(row=,column=1)
labl.grid(row=1,column=1)

window.mainloop()
